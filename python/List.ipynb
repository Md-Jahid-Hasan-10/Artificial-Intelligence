# %% [markdown]
# ### List

# %%
n = int(input()) # len of list
li = []
for i in range(n):
    x = int(input())
    li.append(x)
print(li)
# Out:
#  3
#  3
#  1
#  2
# [3, 1, 2]

# %%
print(li.count(2))
# Out:
# 1

# %%
li.reverse()
li
# Out:
# [2, 1, 3]

# %%
li.sort()
li
# Out:
# [1, 2, 3]

# %%
li.clear()
li
# Out:
# []
