# %% [markdown]
# ## 1. What is Python?
# Python is a high-level, easy-to-read programming language used in AI, Machine Learning, Web Development, and Automation.

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# ## 2. Variables
# Variables are used to store data values. Python does not require explicit declaration of variable types.

# %%
name = "Jahid"
age = 22

print(name)
print(age)
# Out:
# Jahid
# 22

# %% [markdown]
# ## 3. Data Types
# Common data types in Python:
# - int (integer)
# - float (decimal)
# - str (string)
# - bool (boolean)

# %%
a = 10
b = 3.14
c = "Hello"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## 4. Input and Output
# Input allows user to give data, and output displays the result.

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name:  jahid
# Hello jahid

# %% [markdown]
# ## 5. Operators
# Python supports arithmetic operators like:
# + (addition)
# - (subtraction)
# * (multiplication)
# / (division)
# % (modulus)

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Modulus: 1

# %% [markdown]
# ## 6. Conditional Statements (if-else)
# Used to perform different actions based on conditions.

# %%
age = 18

if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %% [markdown]
# ## 7. Loops
# Loops are used to repeat a block of code.
#
# Types:
# - for loop
# - while loop

# %%
# for loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# while loop
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 8. Functions
# Functions are reusable blocks of code.

# %%
def greet(name):
    print("Hello", name)

greet("Jahid")
# Out:
# Hello Jahid

# %% [markdown]
# ## 9. String
# Strings are used to store text data.

# %%
text = "Python"

print(text.upper())
print(text.lower())
print(len(text))
# Out:
# PYTHON
# python
# 6

# %% [markdown]
# ## 10. List
# A list is used to store multiple values in a single variable.

# %%
numbers = [1, 2, 3, 4]
names = ["Jahid", "Ali", "Sara"]

print(numbers)
print(names)
# Out:
# [1, 2, 3, 4]
# ['Jahid', 'Ali', 'Sara']

# %%
# List operations
numbers.append(5)
numbers.remove(2)
numbers.sort()

print(numbers)
# Out:
# [1, 3, 4, 5]
